# %%
import pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-3d7421ed2fbb> in <module>()
# ----> 1 import pd
#
# ImportError: No module named pd

# %%
import os
import math
import numpy as np 

import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('shelter-animal-outcomes.csv.gz'), index_col = 'AnimalID')

# %%
df
# Out:
#       AnimalID        Name             DateTime      OutcomeType  \
# 0      A671945     Hambone  2014-02-12 18:22:00  Return_to_owner
# 1      A656520       Emily  2013-10-13 12:44:00       Euthanasia
# 2      A686464      Pearce  2015-01-31 12:28:00         Adoption
# 3      A683430         NaN  2014-07-11 19:09:00         Transfer
# 4      A667013         NaN  2013-11-15 12:52:00         Transfer
# 5      A677334        Elsa  2014-04-25 13:04:00         Transfer
# 6      A699218       Jimmy  2015-03-28 13:11:00         Transfer
# 7      A701489         NaN  2015-04-30 17:02:00         Transfer
# 8      A671784        Lucy  2014-02-04 17:17:00         Adoption
# 9      A677747         NaN  2014-05-03 07:48:00         Adoption
# 10     A668402         NaN  2013-12-05 15:50:00         Transfer
# 11     A666320         NaN  2013-11-04 14:48:00         Adoption
# 12     A684601      Rocket  2016-02-03 11:27:00         Adoption
# ...

# %%
df.shape
# Out:
# (26729, 10)

# %%
df[df.Breed == "Pit Bull Mix"].shape
# Out:
# (1906, 10)

# %%
df.describe()
# Out:
#        AnimalID   Name             DateTime OutcomeType OutcomeSubtype  \
# count     26729  19038                26729       26729          13117
# unique    26729   6374                22918           5             16
# top     A705677    Max  2015-08-11 00:00:00    Adoption        Partner
# freq          1    136                   19       10769           7816
#
#        AnimalType SexuponOutcome AgeuponOutcome                   Breed  \
# count       26729          26728          26711                   26729
# unique          2              5             44                    1380
# top           Dog  Neutered Male         1 year  Domestic Shorthair Mix
# freq        15595           9779           3969                    8810
#
#               Color
# count         26729
# unique          366
# top     Black/White
# freq           2824

# %%
df.AnimalID.shape
# Out:
# (26729,)

# %%
df.Name.value_counts()
# Out:
# Max            136
# Bella          135
# Charlie        107
# Daisy          106
# Lucy            94
# Buddy           87
# Princess        86
# Rocky           85
# Luna            68
# Jack            66
# Lola            61
# Sadie           58
# Molly           57
# Shadow          57
# Maggie          55
# Coco            55
# Chico           54
# Lily            53
# Oreo            53
# Blue            52
# Lucky           51
# Toby            50
# Cookie          48
# Ginger          48
# Lady            47
# Sam             46
# Duke            45
# Milo            44
# Oliver          44
# Sophie          44
#               ...
# Lady J           1
# Nemesis          1
# Corral           1
# Big Ben          1
# Thomasina        1
# Moscato          1
# Churley          1
# Jeb              1
# Baily            1
# Boom             1
# Jed              1
# Home Girl        1
# Hennesy          1
# Jolli            1
# Tabo             1
# Butterball       1
# ...

# %%
df.Name.mode()
# Out:
# 0    Max
# dtype: object

# %%
df.value_counts
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-271018e0c67f> in <module>()
# ----> 1 df.value_counts
#
# c:\Users\morgane1\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
df.DateTime
# Out:
# AnimalID
# A671945    2014-02-12 18:22:00
# A656520    2013-10-13 12:44:00
# A686464    2015-01-31 12:28:00
# A683430    2014-07-11 19:09:00
# A667013    2013-11-15 12:52:00
# A677334    2014-04-25 13:04:00
# A699218    2015-03-28 13:11:00
# A701489    2015-04-30 17:02:00
# A671784    2014-02-04 17:17:00
# A677747    2014-05-03 07:48:00
# A668402    2013-12-05 15:50:00
# A666320    2013-11-04 14:48:00
# A684601    2016-02-03 11:27:00
# A704702    2015-06-08 16:30:00
# A688584    2015-11-25 15:00:00
# A678825    2014-07-12 12:10:00
# A678050    2014-05-03 16:15:00
# A680028    2014-06-07 12:54:00
# A679010    2014-05-17 11:32:00
# A684787    2014-07-30 17:34:00
# A670658    2014-01-19 15:03:00
# A708812    2015-09-18 15:19:00
# A705262    2015-08-15 14:22:00
# A665781    2013-10-28 16:32:00
# A676333    2014-04-09 17:44:00
# A712750    2015-10-03 15:44:00
# A718832    2016-01-15 17:31:00
# A698777    2015-03-25 18:50:00
# A715348    2015-11-21 13:01:00
# ...

# %%
df.DateTime.tail()
# Out:
# AnimalID
# A702446    2015-05-14 11:56:00
# A718934    2016-01-20 18:59:00
# A698128    2015-03-09 13:33:00
# A677478    2014-04-27 12:22:00
# A706629    2015-07-02 09:00:00
# Name: DateTime, dtype: object

# %%
df.DateTime[-1]
# Out:
# '2015-07-02 09:00:00'

# %%
type(df.DateTime[-1])
#this tells how difficult this will be to calculate from.
# Out:
# str

# %%
a = '2015-07-02 09:00:00'

# %%
b = pd.to_datetime(a)

# %%
b
# Out:
# Timestamp('2015-07-02 09:00:00')

# %%
b.year
# Out:
# 2015

# %%
b.month
# Out:
# 7

# %%
b.day
# Out:
# 2

# %%
df.DateTime = pd.to_datetime(df.DateTime)
#Here we overwrote the date time - this is okay because it's the same data and we don't want to be too repetative.
#Better to overwrite in this case so you don't have a mssive file at the end with excess columns.

# %%
df.DateTime
# Out:
# AnimalID
# A671945   2014-02-12 18:22:00
# A656520   2013-10-13 12:44:00
# A686464   2015-01-31 12:28:00
# A683430   2014-07-11 19:09:00
# A667013   2013-11-15 12:52:00
# A677334   2014-04-25 13:04:00
# A699218   2015-03-28 13:11:00
# A701489   2015-04-30 17:02:00
# A671784   2014-02-04 17:17:00
# A677747   2014-05-03 07:48:00
# A668402   2013-12-05 15:50:00
# A666320   2013-11-04 14:48:00
# A684601   2016-02-03 11:27:00
# A704702   2015-06-08 16:30:00
# A688584   2015-11-25 15:00:00
# A678825   2014-07-12 12:10:00
# A678050   2014-05-03 16:15:00
# A680028   2014-06-07 12:54:00
# A679010   2014-05-17 11:32:00
# A684787   2014-07-30 17:34:00
# A670658   2014-01-19 15:03:00
# A708812   2015-09-18 15:19:00
# A705262   2015-08-15 14:22:00
# A665781   2013-10-28 16:32:00
# A676333   2014-04-09 17:44:00
# A712750   2015-10-03 15:44:00
# A718832   2016-01-15 17:31:00
# A698777   2015-03-25 18:50:00
# A715348   2015-11-21 13:01:00
# A708666   2015-07-30 14:30:00
#                   ...
# ...

# %%
df.OutcomeType.unique()
# Out:
# array(['Return_to_owner', 'Euthanasia', 'Adoption', 'Transfer', 'Died'], dtype=object)

# %%
df.OutcomeType.value_counts()
# Out:
# Adoption           10769
# Transfer            9422
# Return_to_owner     4786
# Euthanasia          1555
# Died                 197
# Name: OutcomeType, dtype: int64

# %%
df.OutcomeSubtype.unique()
# Out:
# array([nan, 'Suffering', 'Foster', 'Partner', 'Offsite', 'SCRP',
#        'Aggressive', 'Behavior', 'Rabies Risk', 'Medical', 'In Kennel',
#        'In Foster', 'Barn', 'Court/Investigation', 'Enroute', 'At Vet',
#        'In Surgery'], dtype=object)

# %%
pd.crosstab(df.OutcomeSubtype, df.OutcomeType)
# Out:
# OutcomeType          Adoption  Died  Euthanasia  Transfer
# OutcomeSubtype
# Aggressive                  0     0         320         0
# At Vet                      0     4           0         0
# Barn                        1     0           0         1
# Behavior                    0     0          86         0
# Court/Investigation         0     0           6         0
# Enroute                     0     8           0         0
# Foster                   1800     0           0         0
# In Foster                   0    52           0         0
# In Kennel                   0   114           0         0
# In Surgery                  0     3           0         0
# Medical                     0     0          66         0
# Offsite                   165     0           0         0
# Partner                     0     0           0      7816
# Rabies Risk                 0     0          74         0
# SCRP                        0     0           0      1599
# ...

# %%
pd.crosstab(df.AnimalType, df.OutcomeType)
# Out:
# OutcomeType  Adoption  Died  Euthanasia  Return_to_owner  Transfer
# AnimalType
# Cat              4272   147         710              500      5505
# Dog              6497    50         845             4286      3917

# %%
pd.crosstab(df.AnimalType, df.Name)
# Out:
# Name   Joanie   Mario  'Stache  007  3Buster  Aaron  Aaron Elvis  Abbadon  \
# 0         NaN     NaN      NaN  NaN      NaN    NaN          NaN      NaN
#
# Name  Abbey  Abbie ...  Zorro  Zsa-Zsa  Zu Zu  Zuchinni  Zues  Zuko  Zulma  \
# 0         1    NaN ...    NaN      NaN    NaN       NaN   NaN   NaN    NaN
#
# Name  Zulu  Zuzu  Zz
# 0      NaN     1 NaN
#
# [1 rows x 6374 columns]

# %%
df.query('AnimalType == "Dog" & (SexuponOutcome == "Spayed Female" | SexuponOutcome == "Intact Male")').Name.value_counts()
# Out:
# Bella           96
# Daisy           79
# Lucy            74
# Princess        63
# Lola            49
# Luna            45
# Sadie           42
# Lady            38
# Maggie          37
# Coco            36
# Molly           34
# Roxy            32
# Rosie           32
# Sasha           31
# Ginger          30
# Cookie          29
# Ruby            26
# Diamond         26
# Chloe           26
# Zoey            25
# Sophie          24
# Lily            23
# Bailey          23
# Minnie          23
# Stella          22
# Gracie          21
# Shadow          21
# Honey           20
# Charlie         20
# Abby            19
#                 ..
# Lois             1
# Drusilla         1
# Shaye            1
# Aquiles          1
# Gorda            1
# Henney           1
# Neko             1
# Nicole           1
# Bon Bon          1
# Gertrude         1
# Ares             1
# Trini            1
# Monkey           1
# Kristy           1
# Yo               1
# Beagle           1
# ...

# %%
df1 = df [df.AnimalType == 'Dog']

# %% [markdown]
# df2 = df1[(df1.SexuponOutcome == 'Intact Male') | (df1.SexuponOutcome == 'Neutered Male')]

# %%
d = {
'Neutered Male': True,
'Spayed Female': True, 
'Intact Male': False,
'Intact Female': False
}

df['Sterlized'] = df['SexuponOutcome'].map(d)

# %%
df
# Out:
#                 Name            DateTime      OutcomeType OutcomeSubtype  \
# AnimalID
# A671945      Hambone 2014-02-12 18:22:00  Return_to_owner            NaN
# A656520        Emily 2013-10-13 12:44:00       Euthanasia      Suffering
# A686464       Pearce 2015-01-31 12:28:00         Adoption         Foster
# A683430          NaN 2014-07-11 19:09:00         Transfer        Partner
# A667013          NaN 2013-11-15 12:52:00         Transfer        Partner
# A677334         Elsa 2014-04-25 13:04:00         Transfer        Partner
# A699218        Jimmy 2015-03-28 13:11:00         Transfer        Partner
# A701489          NaN 2015-04-30 17:02:00         Transfer        Partner
# A671784         Lucy 2014-02-04 17:17:00         Adoption            NaN
# A677747          NaN 2014-05-03 07:48:00         Adoption        Offsite
# A668402          NaN 2013-12-05 15:50:00         Transfer           SCRP
# A666320          NaN 2013-11-04 14:48:00         Adoption            NaN
# ...

# %%
e = {
'Neutered Male'= True,
'Intact Male'= True,
'Spayed Female'= False,
'Intact Female'= False
}
df['Sterilized'] = df['SexuponOutcome'].replace(e)
# Out:
#   File "<ipython-input-89-070422317cb7>", line 2
#     'Neutered Male'= True,
#                    ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#                 Name            DateTime      OutcomeType OutcomeSubtype  \
# AnimalID
# A671945      Hambone 2014-02-12 18:22:00  Return_to_owner            NaN
# A656520        Emily 2013-10-13 12:44:00       Euthanasia      Suffering
# A686464       Pearce 2015-01-31 12:28:00         Adoption         Foster
# A683430          NaN 2014-07-11 19:09:00         Transfer        Partner
# A667013          NaN 2013-11-15 12:52:00         Transfer        Partner
# A677334         Elsa 2014-04-25 13:04:00         Transfer        Partner
# A699218        Jimmy 2015-03-28 13:11:00         Transfer        Partner
# A701489          NaN 2015-04-30 17:02:00         Transfer        Partner
# A671784         Lucy 2014-02-04 17:17:00         Adoption            NaN
# A677747          NaN 2014-05-03 07:48:00         Adoption        Offsite
# A668402          NaN 2013-12-05 15:50:00         Transfer           SCRP
# A666320          NaN 2013-11-04 14:48:00         Adoption            NaN
# ...

# %%
df.OutcomeType.unique()
# Out:
# array(['Return_to_owner', 'Euthanasia', 'Adoption', 'Transfer', 'Died'], dtype=object)

# %%
df['OutcomeType2'] = df.OutcomeType.apply(lambda outcome: 'ReturnToOwner' if outcome == 'Return_to_owner' else outcome)
# .apply is a shortcut function.

# %%
df['OutcomeType2'].value_counts()
# Out:
# Adoption         10769
# Transfer          9422
# ReturnToOwner     4786
# Euthanasia        1555
# Died               197
# Name: OutcomeType2, dtype: int64

# %%
def my_outcome(outcome):
    if outcome == 'Return_to_owner':
        return 'ReturnToOwner'
    else:
        return outcome 
df['OutcomeType3'] = df.OutcomeType.apply(my_outcome)

# %%
df['OutcomeType3'].value_counts()
# Out:
# Adoption         10769
# Transfer          9422
# ReturnToOwner     4786
# Euthanasia        1555
# Died               197
# Name: OutcomeType3, dtype: int64

# %%
df.SexuponOutcome.unique()
# Out:
# array([nan], dtype=object)

# %%
def my_sex(sex): 
    if sex == 'Neutered Male': 
        return 'Male'
    elif sex == 'Intact Male': 
        return 'Male'
    elif sex == 'Spayed Female':
        return 'Female'
    elif sex == 'Intact Female':
        return 'Female'
    else:
        return sex

# %%
'Male' in 'Neutered Male'
# Out:
# True

# %%
'male' in 'Intact Female'
# Out:
# True

# %%
def my_sex(sex): 
    if 'Male' in sex:
        return 'Male'
    elif 'Female' in sex: 
        return 'Female'
    else: 
        return np.nan
#what to do with NaN and Unknown...first question whether or not they are the same thing and combine if you can.

# %%
df.AgeuponOutcome.unique()
# Out:
# array(['1 year', '2 years', '3 weeks', '1 month', '5 months', '4 years',
#        '3 months', '2 weeks', '2 months', '10 months', '6 months',
#        '5 years', '7 years', '3 years', '4 months', '12 years', '9 years',
#        '6 years', '1 weeks', '11 years', '4 weeks', '7 months', '8 years',
#        '11 months', '4 days', '9 months', '8 months', '15 years',
#        '10 years', '1 week', '0 years', '14 years', '3 days', '6 days',
#        '5 days', '5 weeks', '2 days', '16 years', '1 day', '13 years', nan,
#        '17 years', '18 years', '19 years', '20 years'], dtype=object)

# %%
df age_weeks(AgeuponOutcome):
    if year in AgeuponOutcome: 
        return float(AgeuponOutcome)
    elif month in AgeuponOutcome:
        return float(AgeuponOutcome)/12
    elif week in AgeuponOutcome:
        return AgeuponOutcome.float()/52
    elif day in AgeuponOutcome:
        return AgeuponOutcome.float()/362
    else:
        return np.nan
# Out:
#   File "<ipython-input-107-700ada1a91e2>", line 1
#     df age_weeks(AgeuponOutcome):
#                ^
# SyntaxError: invalid syntax

# %%
a = '1 year'
a.split()
# Out:
# ['1', 'year']

# %%
(number,unit) = a.split()

# %%
number = float(number)
# Out:
# 1.0

# %%
def my_age(age): 
    (value,unit) = age.split('')
    value = float(value)
    if ((unit == "day") | (unit == "days")):
        return value
    elif ((unit == "month") | (unit == "weeks"))
        return value * 7 
    elif 'month' in unit: 
        return value * 30.5
# Out:
#   File "<ipython-input-113-d1a232d83670>", line 6
#     elif ((unit == "month") | (unit == "weeks"))
#                                                 ^
# SyntaxError: invalid syntax

# %%
df.Breed.unique()
# Out:
# array(['Shetland Sheepdog Mix', 'Domestic Shorthair Mix', 'Pit Bull Mix',
#        ..., 'Vizsla/Boxer', 'German Shepherd/Australian Kelpie',
#        'Boxer/German Shepherd'], dtype=object)
